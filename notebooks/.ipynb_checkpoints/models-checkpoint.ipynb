# %%
#pip install skforecast

# %%
#pip install pmdarima

# %%
# Data manipulation
# ==============================================================================
import numpy as np
import pandas as pd
import os

# Plots
# ==============================================================================
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
plt.rcParams['lines.linewidth'] = 1.5
# %matplotlib inline

# Modeling and Forecasting
# ==============================================================================
from pmdarima.arima import auto_arima
from statsmodels.tsa.statespace.sarimax import SARIMAX
from skforecast.ForecasterAutoreg import ForecasterAutoreg
from sklearn.ensemble import RandomForestRegressor
from tensorflow.keras.layers import LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Hyperparamter Optmization
# ==============================================================================
from skforecast.model_selection_statsmodels import grid_search_sarimax
from skforecast.model_selection import grid_search_forecaster
from tensorflow.keras.callbacks import EarlyStopping

# Data Preprocess
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.preprocessing import MinMaxScaler

# Model Metrics
# ==============================================================================
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# Warnings configuration
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# %%
rsmes = []
maes = []
r2s = []

# %%
MONTHLY_DATA_PATH = os.path.abspath(r"..\data").replace('\\','/') + '/processed/monthly_rainfall.xlsx'
WEEKLY_DATA_PATH = os.path.abspath(r"..\data").replace('\\','/') + '/processed/weekly_rainfall_avg.xlsx'
DAILY_DATA_PATH = os.path.abspath(r"..\data").replace('\\','/') + '/processed/daily_rainfall.xlsx'

monthly_df = pd.read_excel(MONTHLY_DATA_PATH, 
                           index_col=[0],
                           parse_dates=[0])

monthly_df.index.freq = 'MS'

weekly_df = pd.read_excel(WEEKLY_DATA_PATH,
                          index_col=[0],
                          parse_dates=[0])

daily_df = pd.read_excel(DAILY_DATA_PATH,
                         index_col=[0], 
                         parse_dates=[0])

# %%
monthly_df.head()
# Out:
#             monhtly_avg
# months
# 2014-01-01         60.0
# 2014-02-01        101.5
# 2014-03-01        133.5
# 2014-04-01        117.0
# 2014-05-01         16.5

# %%
monthly_df.shape
# Out:
# (96, 1)

# %%
monthly_df.plot(figsize=(10,5))
plt.show()

# %%
data = monthly_df.copy()

# %%
steps = 24
data_train = data[:-steps]
data_test  = data[-steps:]

print(f"Train dates : {data_train.index.min()} --- {data_train.index.max()}  (n={len(data_train)})")
print(f"Test dates  : {data_test.index.min()} --- {data_test.index.max()}  (n={len(data_test)})")

fig, ax = plt.subplots(figsize=(12,6))
data_train['monhtly_avg'].plot(ax=ax, label='train')
data_test['monhtly_avg'].plot(ax=ax, label='test')
ax.legend();
# Out:
# Train dates : 2014-01-01 00:00:00 --- 2019-12-01 00:00:00  (n=72)
# Test dates  : 2020-01-01 00:00:00 --- 2021-12-01 00:00:00  (n=24)

# %% [markdown]
# SARIMA com autoarima pelo critério AIC # apagar depois

# %%
stepwise_model = auto_arima(data_train, max_order=100, start_p=0, max_p = 4, start_q = 0, max_q = 3, m = 12,
                  seasonal = True, start_P = 0, max_P = 3, start_Q = 0, max_Q = 3,
                  trace = True, error_action = 'ignore', suppress_warnings = True,
                  stepwise = False, information_criterion='aic' )

stepwise_model.fit(data_train)
predictions = stepwise_model.predict(n_periods = steps)
# Out:
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=860.523, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : AIC=847.482, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,2)[12] intercept   : AIC=844.234, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,3)[12] intercept   : AIC=844.382, Time=0.46 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : AIC=839.700, Time=0.13 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(0,0,0)(1,0,2)[12] intercept   : AIC=836.031, Time=0.60 sec
#  ARIMA(0,0,0)(1,0,3)[12] intercept   : AIC=838.127, Time=1.18 sec
#  ARIMA(0,0,0)(2,0,0)[12] intercept   : AIC=838.334, Time=0.36 sec
#  ARIMA(0,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=0.53 sec
#  ARIMA(0,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=0.72 sec
#  ARIMA(0,0,0)(2,0,3)[12] intercept   : AIC=inf, Time=1.36 sec
#  ARIMA(0,0,0)(3,0,0)[12] intercept   : AIC=838.547, Time=0.97 sec
#  ARIMA(0,0,0)(3,0,1)[12] intercept   : AIC=inf, Time=1.15 sec
#  ARIMA(0,0,0)(3,0,2)[12] intercept   : AIC=inf, Time=1.44 sec
#  ARIMA(0,0,0)(3,0,3)[12] intercept   : AIC=inf, Time=2.02 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=851.463, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=844.074, Time=0.18 sec
#  ARIMA(0,0,1)(0,0,2)[12] intercept   : AIC=840.059, Time=0.37 sec
#  ARIMA(0,0,1)(0,0,3)[12] intercept   : AIC=841.642, Time=0.73 sec
#  ARIMA(0,0,1)(1,0,0)[12] intercept   : AIC=838.747, Time=0.21 sec
#  ARIMA(0,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.40 sec
#  ARIMA(0,0,1)(1,0,2)[12] intercept   : AIC=836.786, Time=0.66 sec
#  ARIMA(0,0,1)(1,0,3)[12] intercept   : AIC=839.209, Time=1.33 sec
#  ARIMA(0,0,1)(2,0,0)[12] intercept   : AIC=837.369, Time=0.40 sec
#  ARIMA(0,0,1)(2,0,1)[12] intercept   : AIC=840.956, Time=0.75 sec
#  ARIMA(0,0,1)(2,0,2)[12] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(0,0,1)(2,0,3)[12] intercept   : AIC=inf, Time=1.53 sec
#  ARIMA(0,0,1)(3,0,0)[12] intercept   : AIC=838.923, Time=1.22 sec
#  ARIMA(0,0,1)(3,0,1)[12] intercept   : AIC=inf, Time=1.43 sec
#  ARIMA(0,0,1)(3,0,2)[12] intercept   : AIC=inf, Time=1.58 sec
#  ARIMA(0,0,1)(3,0,3)[12] intercept   : AIC=inf, Time=2.01 sec
#  ARIMA(0,0,2)(0,0,0)[12] intercept   : AIC=849.622, Time=0.12 sec
#  ARIMA(0,0,2)(0,0,1)[12] intercept   : AIC=843.801, Time=0.24 sec
#  ARIMA(0,0,2)(0,0,2)[12] intercept   : AIC=841.408, Time=0.45 sec
#  ARIMA(0,0,2)(0,0,3)[12] intercept   : AIC=843.084, Time=0.96 sec
#  ARIMA(0,0,2)(1,0,0)[12] intercept   : AIC=839.926, Time=0.25 sec
#  ARIMA(0,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.42 sec
#  ARIMA(0,0,2)(1,0,2)[12] intercept   : AIC=839.717, Time=0.76 sec
#  ARIMA(0,0,2)(1,0,3)[12] intercept   : AIC=840.758, Time=1.68 sec
#  ARIMA(0,0,2)(2,0,0)[12] intercept   : AIC=839.140, Time=0.52 sec
#  ARIMA(0,0,2)(2,0,1)[12] intercept   : AIC=842.320, Time=0.79 sec
#  ARIMA(0,0,2)(2,0,2)[12] intercept   : AIC=inf, Time=0.85 sec
#  ARIMA(0,0,2)(2,0,3)[12] intercept   : AIC=inf, Time=1.69 sec
#  ARIMA(0,0,2)(3,0,0)[12] intercept   : AIC=840.642, Time=1.35 sec
#  ARIMA(0,0,2)(3,0,1)[12] intercept   : AIC=inf, Time=1.14 sec
#  ARIMA(0,0,2)(3,0,2)[12] intercept   : AIC=inf, Time=1.86 sec
#  ARIMA(0,0,2)(3,0,3)[12] intercept   : AIC=inf, Time=2.28 sec
#  ARIMA(0,0,3)(0,0,0)[12] intercept   : AIC=851.515, Time=0.15 sec
#  ARIMA(0,0,3)(0,0,1)[12] intercept   : AIC=845.799, Time=0.25 sec
#  ARIMA(0,0,3)(0,0,2)[12] intercept   : AIC=843.343, Time=0.49 sec
#  ARIMA(0,0,3)(0,0,3)[12] intercept   : AIC=844.946, Time=0.83 sec
#  ARIMA(0,0,3)(1,0,0)[12] intercept   : AIC=841.766, Time=0.32 sec
#  ARIMA(0,0,3)(1,0,1)[12] intercept   : AIC=inf, Time=0.50 sec
#  ARIMA(0,0,3)(1,0,2)[12] intercept   : AIC=840.232, Time=0.85 sec
#  ARIMA(0,0,3)(1,0,3)[12] intercept   : AIC=846.869, Time=0.74 sec
#  ARIMA(0,0,3)(2,0,0)[12] intercept   : AIC=840.774, Time=0.55 sec
#  ARIMA(0,0,3)(2,0,1)[12] intercept   : AIC=844.214, Time=0.79 sec
#  ARIMA(0,0,3)(2,0,2)[12] intercept   : AIC=inf, Time=0.93 sec
#  ARIMA(0,0,3)(2,0,3)[12] intercept   : AIC=inf, Time=1.97 sec
#  ARIMA(0,0,3)(3,0,0)[12] intercept   : AIC=842.075, Time=1.48 sec
#  ARIMA(0,0,3)(3,0,1)[12] intercept   : AIC=inf, Time=1.69 sec
#  ARIMA(0,0,3)(3,0,2)[12] intercept   : AIC=inf, Time=1.56 sec
#  ARIMA(0,0,3)(3,0,3)[12] intercept   : AIC=inf, Time=2.29 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=848.515, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=842.664, Time=0.16 sec
#  ARIMA(1,0,0)(0,0,2)[12] intercept   : AIC=839.656, Time=0.36 sec
#  ARIMA(1,0,0)(0,0,3)[12] intercept   : AIC=841.319, Time=0.72 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=838.313, Time=0.16 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=836.681, Time=0.60 sec
#  ARIMA(1,0,0)(1,0,3)[12] intercept   : AIC=838.978, Time=1.36 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=837.282, Time=0.42 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=840.151, Time=0.74 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=0.80 sec
#  ARIMA(1,0,0)(2,0,3)[12] intercept   : AIC=inf, Time=1.62 sec
#  ARIMA(1,0,0)(3,0,0)[12] intercept   : AIC=838.803, Time=1.12 sec
#  ARIMA(1,0,0)(3,0,1)[12] intercept   : AIC=inf, Time=1.43 sec
#  ARIMA(1,0,0)(3,0,2)[12] intercept   : AIC=inf, Time=1.54 sec
#  ARIMA(1,0,0)(3,0,3)[12] intercept   : AIC=inf, Time=1.55 sec
#  ARIMA(1,0,1)(0,0,0)[12] intercept   : AIC=850.505, Time=0.11 sec
#  ARIMA(1,0,1)(0,0,1)[12] intercept   : AIC=844.617, Time=0.14 sec
#  ARIMA(1,0,1)(0,0,2)[12] intercept   : AIC=841.601, Time=0.44 sec
#  ARIMA(1,0,1)(0,0,3)[12] intercept   : AIC=843.281, Time=1.06 sec
#  ARIMA(1,0,1)(1,0,0)[12] intercept   : AIC=840.305, Time=0.28 sec
#  ARIMA(1,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(1,0,1)(1,0,2)[12] intercept   : AIC=839.261, Time=0.78 sec
#  ARIMA(1,0,1)(1,0,3)[12] intercept   : AIC=842.574, Time=1.47 sec
#  ARIMA(1,0,1)(2,0,0)[12] intercept   : AIC=839.250, Time=0.62 sec
#  ARIMA(1,0,1)(2,0,1)[12] intercept   : AIC=inf, Time=0.87 sec
#  ARIMA(1,0,1)(2,0,2)[12] intercept   : AIC=inf, Time=0.87 sec
#  ARIMA(1,0,1)(2,0,3)[12] intercept   : AIC=inf, Time=1.63 sec
#  ARIMA(1,0,1)(3,0,0)[12] intercept   : AIC=inf, Time=1.36 sec
#  ARIMA(1,0,1)(3,0,1)[12] intercept   : AIC=inf, Time=1.54 sec
#  ARIMA(1,0,1)(3,0,2)[12] intercept   : AIC=inf, Time=1.76 sec
#  ARIMA(1,0,1)(3,0,3)[12] intercept   : AIC=inf, Time=2.06 sec
#  ARIMA(1,0,2)(0,0,0)[12] intercept   : AIC=851.522, Time=0.05 sec
#  ARIMA(1,0,2)(0,0,1)[12] intercept   : AIC=845.800, Time=0.32 sec
#  ARIMA(1,0,2)(0,0,2)[12] intercept   : AIC=843.526, Time=0.32 sec
#  ARIMA(1,0,2)(0,0,3)[12] intercept   : AIC=845.217, Time=0.67 sec
#  ARIMA(1,0,2)(1,0,0)[12] intercept   : AIC=841.851, Time=0.35 sec
#  ARIMA(1,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.50 sec
#  ARIMA(1,0,2)(1,0,2)[12] intercept   : AIC=inf, Time=0.79 sec
#  ARIMA(1,0,2)(1,0,3)[12] intercept   : AIC=inf, Time=1.66 sec
#  ARIMA(1,0,2)(2,0,0)[12] intercept   : AIC=inf, Time=0.67 sec
#  ARIMA(1,0,2)(2,0,1)[12] intercept   : AIC=inf, Time=0.88 sec
#  ARIMA(1,0,2)(2,0,2)[12] intercept   : AIC=inf, Time=0.94 sec
#  ARIMA(1,0,2)(2,0,3)[12] intercept   : AIC=inf, Time=2.05 sec
#  ARIMA(1,0,2)(3,0,0)[12] intercept   : AIC=843.035, Time=1.87 sec
#  ARIMA(1,0,2)(3,0,1)[12] intercept   : AIC=inf, Time=1.83 sec
#  ARIMA(1,0,2)(3,0,2)[12] intercept   : AIC=inf, Time=1.77 sec
#  ARIMA(1,0,2)(3,0,3)[12] intercept   : AIC=inf, Time=2.12 sec
#  ARIMA(1,0,3)(0,0,0)[12] intercept   : AIC=853.537, Time=0.12 sec
#  ARIMA(1,0,3)(0,0,1)[12] intercept   : AIC=847.801, Time=0.18 sec
#  ARIMA(1,0,3)(0,0,2)[12] intercept   : AIC=845.370, Time=0.42 sec
#  ARIMA(1,0,3)(0,0,3)[12] intercept   : AIC=846.995, Time=0.69 sec
#  ARIMA(1,0,3)(1,0,0)[12] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(1,0,3)(1,0,1)[12] intercept   : AIC=inf, Time=0.65 sec
#  ARIMA(1,0,3)(1,0,2)[12] intercept   : AIC=inf, Time=0.87 sec
#  ARIMA(1,0,3)(1,0,3)[12] intercept   : AIC=inf, Time=1.52 sec
#  ARIMA(1,0,3)(2,0,0)[12] intercept   : AIC=inf, Time=0.72 sec
#  ARIMA(1,0,3)(2,0,1)[12] intercept   : AIC=inf, Time=0.95 sec
#  ARIMA(1,0,3)(2,0,2)[12] intercept   : AIC=inf, Time=1.12 sec
#  ARIMA(1,0,3)(2,0,3)[12] intercept   : AIC=inf, Time=1.96 sec
#  ARIMA(1,0,3)(3,0,0)[12] intercept   : AIC=inf, Time=1.87 sec
#  ARIMA(1,0,3)(3,0,1)[12] intercept   : AIC=inf, Time=1.78 sec
#  ARIMA(1,0,3)(3,0,2)[12] intercept   : AIC=inf, Time=1.93 sec
#  ARIMA(1,0,3)(3,0,3)[12] intercept   : AIC=inf, Time=3.22 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : AIC=850.501, Time=0.12 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=844.569, Time=0.32 sec
#  ARIMA(2,0,0)(0,0,2)[12] intercept   : AIC=841.569, Time=0.48 sec
#  ARIMA(2,0,0)(0,0,3)[12] intercept   : AIC=843.256, Time=1.21 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=840.298, Time=0.29 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.45 sec
#  ARIMA(2,0,0)(1,0,2)[12] intercept   : AIC=838.481, Time=0.69 sec
#  ARIMA(2,0,0)(1,0,3)[12] intercept   : AIC=841.604, Time=1.68 sec
#  ARIMA(2,0,0)(2,0,0)[12] intercept   : AIC=839.222, Time=0.66 sec
#  ARIMA(2,0,0)(2,0,1)[12] intercept   : AIC=842.006, Time=1.21 sec
#  ARIMA(2,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=0.95 sec
#  ARIMA(2,0,0)(2,0,3)[12] intercept   : AIC=inf, Time=1.90 sec
#  ARIMA(2,0,0)(3,0,0)[12] intercept   : AIC=840.799, Time=1.63 sec
#  ARIMA(2,0,0)(3,0,1)[12] intercept   : AIC=inf, Time=1.81 sec
#  ARIMA(2,0,0)(3,0,2)[12] intercept   : AIC=inf, Time=2.41 sec
#  ARIMA(2,0,0)(3,0,3)[12] intercept   : AIC=inf, Time=2.51 sec
#  ARIMA(2,0,1)(0,0,0)[12] intercept   : AIC=852.163, Time=0.23 sec
#  ARIMA(2,0,1)(0,0,1)[12] intercept   : AIC=846.514, Time=0.24 sec
#  ARIMA(2,0,1)(0,0,2)[12] intercept   : AIC=843.536, Time=0.55 sec
#  ARIMA(2,0,1)(0,0,3)[12] intercept   : AIC=844.392, Time=1.46 sec
#  ARIMA(2,0,1)(1,0,0)[12] intercept   : AIC=842.202, Time=0.31 sec
#  ARIMA(2,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(2,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=0.76 sec
#  ARIMA(2,0,1)(1,0,3)[12] intercept   : AIC=inf, Time=1.95 sec
#  ARIMA(2,0,1)(2,0,0)[12] intercept   : AIC=inf, Time=0.77 sec
#  ARIMA(2,0,1)(2,0,1)[12] intercept   : AIC=inf, Time=0.88 sec
#  ARIMA(2,0,1)(2,0,2)[12] intercept   : AIC=inf, Time=1.07 sec
#  ARIMA(2,0,1)(2,0,3)[12] intercept   : AIC=inf, Time=2.16 sec
#  ARIMA(2,0,1)(3,0,0)[12] intercept   : AIC=inf, Time=2.05 sec
#  ARIMA(2,0,1)(3,0,1)[12] intercept   : AIC=844.770, Time=2.57 sec
#  ARIMA(2,0,1)(3,0,2)[12] intercept   : AIC=inf, Time=2.41 sec
#  ARIMA(2,0,1)(3,0,3)[12] intercept   : AIC=inf, Time=2.83 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=853.452, Time=0.21 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=847.748, Time=0.31 sec
#  ARIMA(2,0,2)(0,0,2)[12] intercept   : AIC=845.281, Time=0.55 sec
#  ARIMA(2,0,2)(0,0,3)[12] intercept   : AIC=846.924, Time=1.08 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=843.797, Time=0.49 sec
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.63 sec
#  ARIMA(2,0,2)(1,0,2)[12] intercept   : AIC=inf, Time=0.93 sec
#  ARIMA(2,0,2)(1,0,3)[12] intercept   : AIC=inf, Time=1.99 sec
#  ARIMA(2,0,2)(2,0,0)[12] intercept   : AIC=842.869, Time=0.79 sec
#  ARIMA(2,0,2)(2,0,1)[12] intercept   : AIC=847.450, Time=1.10 sec
#  ARIMA(2,0,2)(2,0,2)[12] intercept   : AIC=inf, Time=1.26 sec
#  ARIMA(2,0,2)(2,0,3)[12] intercept   : AIC=inf, Time=2.51 sec
#  ARIMA(2,0,2)(3,0,0)[12] intercept   : AIC=844.397, Time=2.12 sec
#  ARIMA(2,0,2)(3,0,1)[12] intercept   : AIC=inf, Time=2.34 sec
#  ARIMA(2,0,2)(3,0,2)[12] intercept   : AIC=inf, Time=2.73 sec
#  ARIMA(2,0,2)(3,0,3)[12] intercept   : AIC=inf, Time=2.60 sec
#  ARIMA(2,0,3)(0,0,0)[12] intercept   : AIC=855.516, Time=0.24 sec
#  ARIMA(2,0,3)(0,0,1)[12] intercept   : AIC=849.795, Time=0.30 sec
#  ARIMA(2,0,3)(0,0,2)[12] intercept   : AIC=847.329, Time=0.56 sec
#  ARIMA(2,0,3)(0,0,3)[12] intercept   : AIC=848.944, Time=1.07 sec
#  ARIMA(2,0,3)(1,0,0)[12] intercept   : AIC=inf, Time=0.49 sec
#  ARIMA(2,0,3)(1,0,1)[12] intercept   : AIC=846.142, Time=0.67 sec
#  ARIMA(2,0,3)(1,0,2)[12] intercept   : AIC=inf, Time=1.01 sec
#  ARIMA(2,0,3)(1,0,3)[12] intercept   : AIC=inf, Time=2.09 sec
#  ARIMA(2,0,3)(2,0,0)[12] intercept   : AIC=inf, Time=1.07 sec
#  ARIMA(2,0,3)(2,0,1)[12] intercept   : AIC=inf, Time=1.08 sec
#  ARIMA(2,0,3)(2,0,2)[12] intercept   : AIC=inf, Time=1.12 sec
#  ARIMA(2,0,3)(2,0,3)[12] intercept   : AIC=inf, Time=2.44 sec
#  ARIMA(2,0,3)(3,0,0)[12] intercept   : AIC=inf, Time=2.22 sec
#  ARIMA(2,0,3)(3,0,1)[12] intercept   : AIC=inf, Time=2.18 sec
#  ARIMA(2,0,3)(3,0,2)[12] intercept   : AIC=inf, Time=2.51 sec
#  ARIMA(2,0,3)(3,0,3)[12] intercept   : AIC=inf, Time=2.54 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : AIC=850.225, Time=0.09 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=845.080, Time=0.29 sec
#  ARIMA(3,0,0)(0,0,2)[12] intercept   : AIC=843.018, Time=0.51 sec
#  ARIMA(3,0,0)(0,0,3)[12] intercept   : AIC=844.651, Time=1.14 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : AIC=841.409, Time=0.30 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.53 sec
#  ARIMA(3,0,0)(1,0,2)[12] intercept   : AIC=840.308, Time=0.77 sec
#  ARIMA(3,0,0)(1,0,3)[12] intercept   : AIC=842.286, Time=1.61 sec
#  ARIMA(3,0,0)(2,0,0)[12] intercept   : AIC=840.610, Time=0.73 sec
#  ARIMA(3,0,0)(2,0,1)[12] intercept   : AIC=843.533, Time=1.09 sec
#  ARIMA(3,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=0.93 sec
#  ARIMA(3,0,0)(2,0,3)[12] intercept   : AIC=inf, Time=1.75 sec
#  ARIMA(3,0,0)(3,0,0)[12] intercept   : AIC=842.211, Time=1.83 sec
#  ARIMA(3,0,0)(3,0,1)[12] intercept   : AIC=inf, Time=1.63 sec
#  ARIMA(3,0,0)(3,0,2)[12] intercept   : AIC=inf, Time=2.22 sec
#  ARIMA(3,0,0)(3,0,3)[12] intercept   : AIC=inf, Time=2.37 sec
#  ARIMA(3,0,1)(0,0,0)[12] intercept   : AIC=840.101, Time=0.27 sec
#  ARIMA(3,0,1)(0,0,1)[12] intercept   : AIC=839.413, Time=0.44 sec
#  ARIMA(3,0,1)(0,0,2)[12] intercept   : AIC=842.022, Time=0.74 sec
#  ARIMA(3,0,1)(0,0,3)[12] intercept   : AIC=841.916, Time=1.68 sec
#  ARIMA(3,0,1)(1,0,0)[12] intercept   : AIC=841.045, Time=0.53 sec
#  ARIMA(3,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.57 sec
#  ARIMA(3,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=0.86 sec
#  ARIMA(3,0,1)(1,0,3)[12] intercept   : AIC=847.711, Time=1.74 sec
#  ARIMA(3,0,1)(2,0,0)[12] intercept   : AIC=inf, Time=0.82 sec
#  ARIMA(3,0,1)(2,0,1)[12] intercept   : AIC=845.078, Time=0.96 sec
#  ARIMA(3,0,1)(2,0,2)[12] intercept   : AIC=inf, Time=1.05 sec
#  ARIMA(3,0,1)(2,0,3)[12] intercept   : AIC=inf, Time=2.17 sec
#  ARIMA(3,0,1)(3,0,0)[12] intercept   : AIC=inf, Time=1.82 sec
#  ARIMA(3,0,1)(3,0,1)[12] intercept   : AIC=846.720, Time=2.08 sec
#  ARIMA(3,0,1)(3,0,2)[12] intercept   : AIC=inf, Time=2.30 sec
#  ARIMA(3,0,1)(3,0,3)[12] intercept   : AIC=inf, Time=2.51 sec
#  ARIMA(3,0,2)(0,0,0)[12] intercept   : AIC=855.735, Time=0.23 sec
#  ARIMA(3,0,2)(0,0,1)[12] intercept   : AIC=849.825, Time=0.17 sec
#  ARIMA(3,0,2)(0,0,2)[12] intercept   : AIC=847.329, Time=0.64 sec
#  ARIMA(3,0,2)(0,0,3)[12] intercept   : AIC=848.935, Time=1.42 sec
#  ARIMA(3,0,2)(1,0,0)[12] intercept   : AIC=inf, Time=0.49 sec
#  ARIMA(3,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.63 sec
#  ARIMA(3,0,2)(1,0,2)[12] intercept   : AIC=inf, Time=1.11 sec
#  ARIMA(3,0,2)(1,0,3)[12] intercept   : AIC=inf, Time=1.96 sec
#  ARIMA(3,0,2)(2,0,0)[12] intercept   : AIC=inf, Time=1.02 sec
#  ARIMA(3,0,2)(2,0,1)[12] intercept   : AIC=845.645, Time=1.22 sec
#  ARIMA(3,0,2)(2,0,2)[12] intercept   : AIC=inf, Time=1.26 sec
#  ARIMA(3,0,2)(2,0,3)[12] intercept   : AIC=inf, Time=2.56 sec
#  ARIMA(3,0,2)(3,0,0)[12] intercept   : AIC=inf, Time=2.17 sec
#  ARIMA(3,0,2)(3,0,1)[12] intercept   : AIC=848.328, Time=2.10 sec
#  ARIMA(3,0,2)(3,0,2)[12] intercept   : AIC=inf, Time=2.74 sec
#  ARIMA(3,0,2)(3,0,3)[12] intercept   : AIC=inf, Time=3.86 sec
#  ARIMA(3,0,3)(0,0,0)[12] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(3,0,3)(0,0,1)[12] intercept   : AIC=inf, Time=0.53 sec
#  ARIMA(3,0,3)(0,0,2)[12] intercept   : AIC=inf, Time=0.86 sec
#  ARIMA(3,0,3)(0,0,3)[12] intercept   : AIC=inf, Time=1.88 sec
#  ARIMA(3,0,3)(1,0,0)[12] intercept   : AIC=inf, Time=0.63 sec
#  ARIMA(3,0,3)(1,0,1)[12] intercept   : AIC=inf, Time=0.87 sec
#  ARIMA(3,0,3)(1,0,2)[12] intercept   : AIC=inf, Time=1.23 sec
#  ARIMA(3,0,3)(1,0,3)[12] intercept   : AIC=inf, Time=2.73 sec
#  ARIMA(3,0,3)(2,0,0)[12] intercept   : AIC=844.693, Time=1.03 sec
#  ARIMA(3,0,3)(2,0,1)[12] intercept   : AIC=inf, Time=1.21 sec
#  ARIMA(3,0,3)(2,0,2)[12] intercept   : AIC=inf, Time=1.26 sec
#  ARIMA(3,0,3)(2,0,3)[12] intercept   : AIC=inf, Time=2.41 sec
#  ARIMA(3,0,3)(3,0,0)[12] intercept   : AIC=inf, Time=2.41 sec
#  ARIMA(3,0,3)(3,0,1)[12] intercept   : AIC=inf, Time=2.39 sec
#  ARIMA(3,0,3)(3,0,2)[12] intercept   : AIC=inf, Time=2.73 sec
#  ARIMA(3,0,3)(3,0,3)[12] intercept   : AIC=inf, Time=2.97 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : AIC=850.019, Time=0.13 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : AIC=845.916, Time=0.27 sec
#  ARIMA(4,0,0)(0,0,2)[12] intercept   : AIC=844.615, Time=0.38 sec
#  ARIMA(4,0,0)(0,0,3)[12] intercept   : AIC=846.307, Time=1.29 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : AIC=842.933, Time=0.35 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.55 sec
#  ARIMA(4,0,0)(1,0,2)[12] intercept   : AIC=843.023, Time=0.82 sec
#  ARIMA(4,0,0)(1,0,3)[12] intercept   : AIC=848.222, Time=0.98 sec
#  ARIMA(4,0,0)(2,0,0)[12] intercept   : AIC=842.445, Time=0.82 sec
#  ARIMA(4,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=1.07 sec
#  ARIMA(4,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=1.11 sec
#  ARIMA(4,0,0)(2,0,3)[12] intercept   : AIC=inf, Time=1.97 sec
#  ARIMA(4,0,0)(3,0,0)[12] intercept   : AIC=846.577, Time=2.01 sec
#  ARIMA(4,0,0)(3,0,1)[12] intercept   : AIC=inf, Time=1.97 sec
#  ARIMA(4,0,0)(3,0,2)[12] intercept   : AIC=inf, Time=2.20 sec
#  ARIMA(4,0,0)(3,0,3)[12] intercept   : AIC=inf, Time=2.65 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : AIC=842.199, Time=0.30 sec
#  ARIMA(4,0,1)(0,0,1)[12] intercept   : AIC=841.484, Time=0.49 sec
#  ARIMA(4,0,1)(0,0,2)[12] intercept   : AIC=842.776, Time=0.88 sec
#  ARIMA(4,0,1)(0,0,3)[12] intercept   : AIC=844.598, Time=1.94 sec
#  ARIMA(4,0,1)(1,0,0)[12] intercept   : AIC=845.043, Time=0.54 sec
#  ARIMA(4,0,1)(1,0,1)[12] intercept   : AIC=845.688, Time=0.70 sec
#  ARIMA(4,0,1)(1,0,2)[12] intercept   : AIC=847.029, Time=0.95 sec
#  ARIMA(4,0,1)(1,0,3)[12] intercept   : AIC=848.704, Time=1.95 sec
#  ARIMA(4,0,1)(2,0,0)[12] intercept   : AIC=inf, Time=1.08 sec
#  ARIMA(4,0,1)(2,0,1)[12] intercept   : AIC=846.425, Time=1.12 sec
#  ARIMA(4,0,1)(2,0,2)[12] intercept   : AIC=inf, Time=1.23 sec
#  ARIMA(4,0,1)(2,0,3)[12] intercept   : AIC=inf, Time=2.39 sec
#  ARIMA(4,0,1)(3,0,0)[12] intercept   : AIC=inf, Time=2.16 sec
#  ARIMA(4,0,1)(3,0,1)[12] intercept   : AIC=inf, Time=2.10 sec
#  ARIMA(4,0,1)(3,0,2)[12] intercept   : AIC=inf, Time=2.43 sec
#  ARIMA(4,0,1)(3,0,3)[12] intercept   : AIC=inf, Time=2.69 sec
#  ARIMA(4,0,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(4,0,2)(0,0,1)[12] intercept   : AIC=850.295, Time=0.51 sec
#  ARIMA(4,0,2)(0,0,2)[12] intercept   : AIC=848.670, Time=0.81 sec
#  ARIMA(4,0,2)(0,0,3)[12] intercept   : AIC=850.158, Time=1.94 sec
#  ARIMA(4,0,2)(1,0,0)[12] intercept   : AIC=inf, Time=0.59 sec
#  ARIMA(4,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.72 sec
#  ARIMA(4,0,2)(1,0,2)[12] intercept   : AIC=inf, Time=1.04 sec
#  ARIMA(4,0,2)(1,0,3)[12] intercept   : AIC=inf, Time=2.20 sec
#  ARIMA(4,0,2)(2,0,0)[12] intercept   : AIC=inf, Time=1.07 sec
#  ARIMA(4,0,2)(2,0,1)[12] intercept   : AIC=847.423, Time=1.31 sec
#  ARIMA(4,0,2)(2,0,2)[12] intercept   : AIC=inf, Time=1.46 sec
#  ARIMA(4,0,2)(2,0,3)[12] intercept   : AIC=inf, Time=2.47 sec
#  ARIMA(4,0,2)(3,0,0)[12] intercept   : AIC=inf, Time=2.17 sec
#  ARIMA(4,0,2)(3,0,1)[12] intercept   : AIC=848.487, Time=2.32 sec
#  ARIMA(4,0,2)(3,0,2)[12] intercept   : AIC=inf, Time=2.87 sec
#  ARIMA(4,0,2)(3,0,3)[12] intercept   : AIC=inf, Time=3.02 sec
#  ARIMA(4,0,3)(0,0,0)[12] intercept   : AIC=858.420, Time=0.39 sec
#  ARIMA(4,0,3)(0,0,1)[12] intercept   : AIC=inf, Time=0.65 sec
#  ARIMA(4,0,3)(0,0,2)[12] intercept   : AIC=848.596, Time=1.09 sec
#  ARIMA(4,0,3)(0,0,3)[12] intercept   : AIC=850.255, Time=2.56 sec
#  ARIMA(4,0,3)(1,0,0)[12] intercept   : AIC=inf, Time=0.72 sec
#  ARIMA(4,0,3)(1,0,1)[12] intercept   : AIC=inf, Time=1.03 sec
#  ARIMA(4,0,3)(1,0,2)[12] intercept   : AIC=inf, Time=1.24 sec
#  ARIMA(4,0,3)(1,0,3)[12] intercept   : AIC=inf, Time=2.55 sec
#  ARIMA(4,0,3)(2,0,0)[12] intercept   : AIC=inf, Time=1.21 sec
#  ARIMA(4,0,3)(2,0,1)[12] intercept   : AIC=inf, Time=1.30 sec
#  ARIMA(4,0,3)(2,0,2)[12] intercept   : AIC=inf, Time=1.50 sec
#  ARIMA(4,0,3)(2,0,3)[12] intercept   : AIC=inf, Time=3.58 sec
#  ARIMA(4,0,3)(3,0,0)[12] intercept   : AIC=inf, Time=2.67 sec
#  ARIMA(4,0,3)(3,0,1)[12] intercept   : AIC=inf, Time=2.77 sec
#  ARIMA(4,0,3)(3,0,2)[12] intercept   : AIC=inf, Time=3.31 sec
#  ARIMA(4,0,3)(3,0,3)[12] intercept   : AIC=inf, Time=3.31 sec
#
# Best model:  ARIMA(0,0,0)(1,0,2)[12] intercept
# Total fit time: 386.883 seconds

# %%
# Plot
# ==============================================================================
fig, ax = plt.subplots(figsize=(12,6))
data_train['monhtly_avg'].plot(ax=ax, label='train')
data_test['monhtly_avg'].plot(ax=ax, label='test')
predictions.plot(ax=ax, label='predictions')
ax.legend();

error_mse = mean_squared_error(
                y_true = data_test,
                y_pred = predictions
            )

error_mae = mean_absolute_error(
                y_true = data_test,
                y_pred = predictions
            )

rsmes.append(error_mse**0.5)

maes.append(error_mae)

print(f"Mean Absolute Error (MAE): {error_mae:.2f}")

print(f"Root Mean Squared Error (RSME): {error_mse**0.5:.2f}")

print(f"Correlation Coefficient: {r2_score(data_test, predictions):.2f}")
r2s.append(r2_score(data_test, predictions))




# Vamos criar um gráfico para comparar os Valores Reais com os Preditos
fig = plt.figure(figsize=(8,8))
l = plt.plot(predictions.values, data_test.values, 'bo')
plt.setp(l, markersize=10)
plt.setp(l, markerfacecolor='C0')
plt.title('Comparação Valor Predito x Valor Real', fontsize=12)
plt.ylabel("True Value", fontsize=12)
plt.xlabel("Predict Value", fontsize=12)

# mostra os valores preditos e originais
xl = np.arange(min(data_test.values), 1.2*max(data_test.values),(max(data_test.values)-min(data_test.values))/10)
yl = xl
plt.plot(xl, yl, 'r--')
plt.show()
# Out:
# Mean Absolute Error (MAE): 67.35
# Root Mean Squared Error (RSME): 87.23
# Correlation Coefficient: 0.45

# %% [markdown]
# SARIMA com GridSearch # apagar depois

# %%
list_order = [(p, d, q) for p in range(1) for d in range(3) for q in range(4)]
list_order_s = [(P, D, Q, 12) for P in range(3) for D in range(3) for Q in range(4)]

param_grid = {'order': list_order,
             'seasonal_order': list_order_s}

results_grid = grid_search_sarimax(
                y = data_train,
                param_grid = param_grid,
                initial_train_size = len(data_train) - steps,
                fixed_train_size = True,
                steps = 1,
                metric = 'mean_squared_error',
                refit = False,
                verbose = False)
results_grid
# Out:
# root       INFO  Number of models compared: 432
# 100%|███████████████████████████████████████████████████| 432/432 [08:15<00:00,  1.15s/it]
#                                                 params        metric  \
# 241  {'order': (0, 1, 2), 'seasonal_order': (2, 0, ...  6.093211e+03
# 231  {'order': (0, 1, 2), 'seasonal_order': (1, 0, ...  6.208625e+03
# 267  {'order': (0, 1, 3), 'seasonal_order': (1, 0, ...  6.227235e+03
# 243  {'order': (0, 1, 2), 'seasonal_order': (2, 0, ...  6.285121e+03
# 266  {'order': (0, 1, 3), 'seasonal_order': (1, 0, ...  6.304254e+03
# ..                                                 ...           ...
# 322  {'order': (0, 2, 0), 'seasonal_order': (2, 2, ...  9.770380e+04
# 321  {'order': (0, 2, 0), 'seasonal_order': (2, 2, ...  1.053091e+05
# 323  {'order': (0, 2, 0), 'seasonal_order': (2, 2, ...  1.078912e+05
# 296  {'order': (0, 2, 0), 'seasonal_order': (0, 2, ...  1.663596e+05
# 394  {'order': (0, 2, 2), 'seasonal_order': (2, 2, ...  5.142178e+10
#
#          order seasonal_order trend
# 241  (0, 1, 2)  (2, 0, 1, 12)  None
# 231  (0, 1, 2)  (1, 0, 3, 12)  None
# 267  (0, 1, 3)  (1, 0, 3, 12)  None
# 243  (0, 1, 2)  (2, 0, 3, 12)  None
# 266  (0, 1, 3)  (1, 0, 2, 12)  None
# ..         ...            ...   ...
# 322  (0, 2, 0)  (2, 2, 2, 12)  None
# 321  (0, 2, 0)  (2, 2, 1, 12)  None
# 323  (0, 2, 0)  (2, 2, 3, 12)  None
# 296  (0, 2, 0)  (0, 2, 0, 12)  None
# 394  (0, 2, 2)  (2, 2, 2, 12)  None
#
# [432 rows x 5 columns]

# %%
order = results_grid.iloc[0,2]
order_s = results_grid.iloc[0,3]
trend = results_grid.iloc[0,4]

modelo = SARIMAX(data_train, order = order, seasonal_order= order_s, trend = trend)

results = modelo.fit()

predictions = results.predict(start = len(data_train), end=len(data_train)+len(data_test)-1)

# %%
# Plot
# ==============================================================================
fig, ax = plt.subplots(figsize=(12,6))
data_train['monhtly_avg'].plot(ax=ax, label='train')
data_test['monhtly_avg'].plot(ax=ax, label='test')
predictions.plot(ax=ax, label='predictions')
ax.legend();

error_mse = mean_squared_error(
                y_true = data_test,
                y_pred = predictions
            )

error_mae = mean_absolute_error(
                y_true = data_test,
                y_pred = predictions
            )

rsmes.append(error_mse**0.5)

maes.append(error_mae)

print(f"Mean Absolute Error (MAE): {error_mae:.2f}")

print(f"Root Mean Squared Error (RSME): {error_mse**0.5:.2f}")

print(f"Correlation Coefficient: {r2_score(data_test, predictions):.2f}")
r2s.append(r2_score(data_test, predictions))




# Vamos criar um gráfico para comparar os Valores Reais com os Preditos
fig = plt.figure(figsize=(8,8))
l = plt.plot(predictions.values, data_test.values, 'bo')
plt.setp(l, markersize=10)
plt.setp(l, markerfacecolor='C0')
plt.title('Comparação Valor Predito x Valor Real', fontsize=12)
plt.ylabel("True Value", fontsize=12)
plt.xlabel("Predict Value", fontsize=12)

# mostra os valores preditos e originais
xl = np.arange(min(data_test.values), 1.2*max(data_test.values),(max(data_test.values)-min(data_test.values))/10)
yl = xl
plt.plot(xl, yl, 'r--')
plt.show()
# Out:
# Mean Absolute Error (MAE): 66.97
# Root Mean Squared Error (RSME): 87.15
# Correlation Coefficient: 0.45

# %% [markdown]
# Random Forest baseLine (sem gridsearch) #apagar depois

# %%
# Create and train forecaster
# ==============================================================================
forecaster = ForecasterAutoreg(
                regressor = RandomForestRegressor(random_state=123),
                lags      = 3
             )

forecaster.fit(data_train['monhtly_avg'])
forecaster
# Out:
# =================
# ForecasterAutoreg
# =================
# Regressor: RandomForestRegressor(random_state=123)
# Lags: [1 2 3]
# Window size: 3
# Included exogenous: False
# Type of exogenous variable: None
# Exogenous variables names: None
# Training range: [Timestamp('2014-01-01 00:00:00'), Timestamp('2019-12-01 00:00:00')]
# Training index type: DatetimeIndex
# Training index frequency: MS
# Regressor parameters: {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': 123, 'verbose': 0, 'warm_start': False}
# Creation date: 2022-09-29 23:44:28
# Last fit date: 2022-09-29 23:44:28
# Skforecast version: 0.4.3

# %%
# Predictions
# ==============================================================================
predictions = forecaster.predict(steps=steps)
predictions.head(5)
# Out:
# 2020-01-01    155.294
# 2020-02-01    155.925
# 2020-03-01    204.255
# 2020-04-01    192.975
# 2020-05-01    154.549
# Freq: MS, Name: pred, dtype: float64

# %%
# Plot
# ==============================================================================
fig, ax = plt.subplots(figsize=(12,6))
data_train['monhtly_avg'].plot(ax=ax, label='train')
data_test['monhtly_avg'].plot(ax=ax, label='test')
predictions.plot(ax=ax, label='predictions')
ax.legend();


error_mse = mean_squared_error(
                y_true = data_test,
                y_pred = predictions
            )

error_mae = mean_absolute_error(
                y_true = data_test,
                y_pred = predictions
            )

print(f"Mean Absolute Error (MAE): {error_mae:.2f}")

print(f"Root Mean Squared Error (RSME): {error_mse**0.5:.2f}")

print(f"Correlation Coefficient: {r2_score(data_test, predictions):.2f}")

# Vamos criar um gráfico para comparar os Valores Reais com os Preditos
fig = plt.figure(figsize=(8,8))
l = plt.plot(predictions.values, data_test.values, 'bo')
plt.setp(l, markersize=10)
plt.setp(l, markerfacecolor='C0')
plt.title('Comparação Valor Predito x Valor Real', fontsize=12)
plt.ylabel("True Value", fontsize=12)
plt.xlabel("Predict Value", fontsize=12)

# mostra os valores preditos e originais
xl = np.arange(min(data_test.values), 1.2*max(data_test.values),(max(data_test.values)-min(data_test.values))/10)
yl = xl
plt.plot(xl, yl, 'r--')
plt.show()
# Out:
# Mean Absolute Error (MAE): 120.64
# Root Mean Squared Error (RSME): 137.09
# Correlation Coefficient: -0.35

# %% [markdown]
# Random Forest (com gridsearch) #apagar depois

# %%
# Hyperparameter Grid search
# ==============================================================================
forecaster = ForecasterAutoreg(
                regressor = RandomForestRegressor(random_state=123),
                lags      = 3 # This value will be replaced in the grid search
             )

# Lags used as predictors
lags_grid = range(2,9)

# Regressor's hyperparameters
param_grid = {'n_estimators': [100, 500],
              'max_depth': [8, 10, 12],
             }

results_grid = grid_search_forecaster(
                        forecaster         = forecaster,
                        y                  = data_train['monhtly_avg'],
                        param_grid         = param_grid,
                        lags_grid          = lags_grid,
                        steps              = steps,
                        refit              = True,
                        metric             = 'mean_squared_error',
                        initial_train_size = int(len(data_train)*0.5),
                        fixed_train_size   = False,
                        return_best        = True,
                        verbose            = False
               )
# Out:
# Number of models compared: 42
# loop lags_grid:   0%|                                               | 0/7 [00:00<?, ?it/s]
# loop param_grid:   0%|                                              | 0/6 [00:00<?, ?it/s]
# loop param_grid:  17%|██████▎                               | 1/6 [00:00<00:03,  1.62it/s]
# loop param_grid:  33%|████████████▋                         | 2/6 [00:03<00:07,  1.95s/it]
# loop param_grid:  50%|███████████████████                   | 3/6 [00:04<00:03,  1.33s/it]
# loop param_grid:  67%|█████████████████████████▎            | 4/6 [00:06<00:03,  1.93s/it]
# loop param_grid:  83%|███████████████████████████████▋      | 5/6 [00:07<00:01,  1.46s/it]
# loop param_grid: 100%|██████████████████████████████████████| 6/6 [00:10<00:00,  1.94s/it]
# loop lags_grid:  14%|█████▌                                 | 1/7 [00:10<01:02, 10.44s/it]
# loop param_grid:   0%|                                              | 0/6 [00:00<?, ?it/s]
# loop param_grid:  17%|██████▎                               | 1/6 [00:00<00:02,  1.67it/s]
# loop param_grid:  33%|████████████▋                         | 2/6 [00:03<00:07,  1.93s/it]
# loop param_grid:  50%|███████████████████                   | 3/6 [00:04<00:03,  1.32s/it]
# loop param_grid:  67%|█████████████████████████▎            | 4/6 [00:06<00:03,  1.93s/it]
# loop param_grid:  83%|███████████████████████████████▋      | 5/6 [00:07<00:01,  1.45s/it]
# loop param_grid: 100%|██████████████████████████████████████| 6/6 [00:10<00:00,  1.93s/it]
# loop lags_grid:  29%|███████████▏                           | 2/7 [00:20<00:52, 10.41s/it]
# loop param_grid:   0%|                                              | 0/6 [00:00<?, ?it/s]
# loop param_grid:  17%|██████▎                               | 1/6 [00:00<00:03,  1.62it/s]
# loop param_grid:  33%|████████████▋                         | 2/6 [00:03<00:07,  1.92s/it]
# loop param_grid:  50%|███████████████████                   | 3/6 [00:04<00:03,  1.32s/it]
# loop param_grid:  67%|█████████████████████████▎            | 4/6 [00:06<00:03,  1.92s/it]
# loop param_grid:  83%|███████████████████████████████▋      | 5/6 [00:07<00:01,  1.44s/it]
# loop param_grid: 100%|██████████████████████████████████████| 6/6 [00:10<00:00,  1.93s/it]
# loop lags_grid:  43%|████████████████▋                      | 3/7 [00:31<00:41, 10.39s/it]
# loop param_grid:   0%|                                              | 0/6 [00:00<?, ?it/s]
# loop param_grid:  17%|██████▎                               | 1/6 [00:00<00:03,  1.62it/s]
# loop param_grid:  33%|████████████▋                         | 2/6 [00:03<00:07,  1.93s/it]
# loop param_grid:  50%|███████████████████                   | 3/6 [00:04<00:03,  1.32s/it]
# loop param_grid:  67%|█████████████████████████▎            | 4/6 [00:06<00:03,  1.93s/it]
# loop param_grid:  83%|███████████████████████████████▋      | 5/6 [00:07<00:01,  1.45s/it]
# loop param_grid: 100%|██████████████████████████████████████| 6/6 [00:10<00:00,  1.92s/it]
# loop lags_grid:  57%|██████████████████████▎                | 4/7 [00:41<00:31, 10.38s/it]
# loop param_grid:   0%|                                              | 0/6 [00:00<?, ?it/s]
# loop param_grid:  17%|██████▎                               | 1/6 [00:00<00:03,  1.65it/s]
# loop param_grid:  33%|████████████▋                         | 2/6 [00:03<00:07,  1.94s/it]
# loop param_grid:  50%|███████████████████                   | 3/6 [00:04<00:03,  1.33s/it]
# loop param_grid:  67%|█████████████████████████▎            | 4/6 [00:07<00:04,  2.29s/it]
# loop param_grid:  83%|███████████████████████████████▋      | 5/6 [00:08<00:01,  1.68s/it]
# loop param_grid: 100%|██████████████████████████████████████| 6/6 [00:11<00:00,  2.10s/it]
# loop lags_grid:  71%|███████████████████████████▊           | 5/7 [00:52<00:21, 10.73s/it]
# loop param_grid:   0%|                                              | 0/6 [00:00<?, ?it/s]
# loop param_grid:  17%|██████▎                               | 1/6 [00:00<00:03,  1.65it/s]
# loop param_grid:  33%|████████████▋                         | 2/6 [00:03<00:07,  2.00s/it]
# loop param_grid:  50%|███████████████████                   | 3/6 [00:04<00:04,  1.37s/it]
# loop param_grid:  67%|█████████████████████████▎            | 4/6 [00:07<00:03,  1.98s/it]
# loop param_grid:  83%|███████████████████████████████▋      | 5/6 [00:07<00:01,  1.49s/it]
# loop param_grid: 100%|██████████████████████████████████████| 6/6 [00:10<00:00,  2.07s/it]
# loop lags_grid:  86%|█████████████████████████████████▍     | 6/7 [01:03<00:10, 10.80s/it]
# loop param_grid:   0%|                                              | 0/6 [00:00<?, ?it/s]
# loop param_grid:  17%|██████▎                               | 1/6 [00:00<00:03,  1.51it/s]
# loop param_grid:  33%|████████████▋                         | 2/6 [00:03<00:08,  2.10s/it]
# loop param_grid:  50%|███████████████████                   | 3/6 [00:04<00:04,  1.45s/it]
# loop param_grid:  67%|█████████████████████████▎            | 4/6 [00:07<00:04,  2.06s/it]
# loop param_grid:  83%|███████████████████████████████▋      | 5/6 [00:08<00:01,  1.55s/it]
# loop param_grid: 100%|██████████████████████████████████████| 6/6 [00:10<00:00,  1.99s/it]
# loop lags_grid: 100%|███████████████████████████████████████| 7/7 [01:14<00:00, 10.69s/it]
# `Forecaster` refitted using the best-found lags and parameters, and the whole data set:
#   Lags: [1 2 3 4 5 6 7]
#   Parameters: {'max_depth': 10, 'n_estimators': 100}
#   Backtesting metric: 7162.66611782388

# %%
# Grid Search results
# ==============================================================================
results_grid.head()
# Out:
#                      lags                                  params  \
# 32  [1, 2, 3, 4, 5, 6, 7]  {'max_depth': 10, 'n_estimators': 100}
# 34  [1, 2, 3, 4, 5, 6, 7]  {'max_depth': 12, 'n_estimators': 100}
# 25     [1, 2, 3, 4, 5, 6]   {'max_depth': 8, 'n_estimators': 500}
# 26     [1, 2, 3, 4, 5, 6]  {'max_depth': 10, 'n_estimators': 100}
# 29     [1, 2, 3, 4, 5, 6]  {'max_depth': 12, 'n_estimators': 500}
#
#          metric  max_depth  n_estimators
# 32  7162.666118         10           100
# 34  7165.072277         12           100
# 25  7206.822142          8           500
# 26  7207.893096         10           100
# 29  7214.053373         12           500

# %%
predictions = forecaster.predict(steps=steps)
predictions.head(5)
# Out:
# 2020-01-01    182.748667
# 2020-02-01    179.233667
# 2020-03-01    144.898750
# 2020-04-01     86.920139
# 2020-05-01     40.631389
# Freq: MS, Name: pred, dtype: float64

# %%
# Plot
# ==============================================================================
fig, ax = plt.subplots(figsize=(12,6))
data_train['monhtly_avg'].plot(ax=ax, label='train')
data_test['monhtly_avg'].plot(ax=ax, label='test')
predictions.plot(ax=ax, label='predictions')
ax.legend();


error_mse = mean_squared_error(
                y_true = data_test,
                y_pred = predictions
            )

error_mae = mean_absolute_error(
                y_true = data_test,
                y_pred = predictions
            )

rsmes.append(error_mse**0.5)

maes.append(error_mae)

print(f"Mean Absolute Error (MAE): {error_mae:.2f}")

print(f"Root Mean Squared Error (RSME): {error_mse**0.5:.2f}")

print(f"Correlation Coefficient: {r2_score(data_test, predictions):.2f}")
r2s.append(r2_score(data_test, predictions))

# Vamos criar um gráfico para comparar os Valores Reais com os Preditos
fig = plt.figure(figsize=(8,8))
l = plt.plot(predictions.values, data_test.values, 'bo')
plt.setp(l, markersize=10)
plt.setp(l, markerfacecolor='C0')
plt.title('Comparação Valor Predito x Valor Real', fontsize=12)
plt.ylabel("True Value", fontsize=12)
plt.xlabel("Predict Value", fontsize=12)

# mostra os valores preditos e originais
xl = np.arange(min(data_test.values), 1.2*max(data_test.values),(max(data_test.values)-min(data_test.values))/10)
yl = xl
plt.plot(xl, yl, 'r--')
plt.show()
# Out:
# Mean Absolute Error (MAE): 61.14
# Root Mean Squared Error (RSME): 79.38
# Correlation Coefficient: 0.55

# %% [markdown]
# rede LSTM #apagar depois

# %%
scaler = MinMaxScaler()
scaled_train = scaler.fit_transform(data_train)
scaled_test = scaler.transform(data_test)

# %%
n_input = 12
n_output = 12
n_features = 1

generator = TimeseriesGenerator(scaled_train, 
                                scaled_train, 
                                length = n_input,
                                batch_size = 1)

# %%
X, y = generator[0]

# %%
# Entendendo a separação em lotes e a previsão esperada
print('Dados Esperados por lote e previsão')
print(f'Primeiro Lote: \n{X.flatten()}');
print(f'Previsão: \n {y}');
# Out:
# Dados Esperados por lote e previsão
# Primeiro Lote:
# [0.19047619 0.32222222 0.42380952 0.37142857 0.05238095 0.01587302
#  0.16507937 0.         0.12380952 0.11111111 0.83174603 0.62539683]
# Previsão:
#  [[0.31904762]]

# %%
model = Sequential([
            LSTM(100, activation='relu', input_shape=(n_input, n_features)),
            Dense(1, activation = 'sigmoid')])
model.compile(optimizer='adam', loss='mse')
model.fit(generator, epochs = 50)

test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(data_test)):
    # obter a previsão de tempo 1 antecipadamente ([0] é para pegar apenas o número em vez de [array])
    current_pred = model.predict(current_batch)[0]
    
    # predição
    test_predictions.append(current_pred) 
    
    # atualize a rodada para agora incluir a previsão e descartar o primeiro valor
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# Epoch 1/50
# 60/60 [==============================] - 2s 4ms/step - loss: 0.0958
# Epoch 2/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0877
# Epoch 3/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0847
# Epoch 4/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0763
# Epoch 5/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0691
# Epoch 6/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0671
# Epoch 7/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0625
# Epoch 8/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0579
# Epoch 9/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0570
# Epoch 10/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0563
# Epoch 11/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0625
# Epoch 12/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0575
# Epoch 13/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0515
# Epoch 14/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0484
# Epoch 15/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0499
# Epoch 16/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0481
# Epoch 17/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0474
# Epoch 18/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0482
# Epoch 19/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0452
# Epoch 20/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0436
# Epoch 21/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0484
# Epoch 22/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0469
# Epoch 23/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0488
# Epoch 24/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0429
# Epoch 25/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0478
# Epoch 26/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0440
# Epoch 27/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0434
# Epoch 28/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0473
# Epoch 29/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0433
# Epoch 30/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0486
# Epoch 31/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0421
# Epoch 32/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0454
# Epoch 33/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0416
# Epoch 34/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0449
# Epoch 35/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0431
# Epoch 36/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0436
# Epoch 37/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0445
# Epoch 38/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0426
# Epoch 39/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0437
# Epoch 40/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0444
# Epoch 41/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0393
# Epoch 42/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0429
# Epoch 43/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0426
# Epoch 44/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0407
# Epoch 45/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0415
# Epoch 46/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0408
# Epoch 47/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0421
# Epoch 48/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0406
# Epoch 49/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0443
# Epoch 50/50
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0431
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step

# %%
predictions = scaler.inverse_transform(test_predictions)
predictions = [prediction[0] for prediction in predictions]
predictions = pd.DataFrame(predictions, index = data_test.index, columns = ['monhtly_avg'])


# Plot
# ==============================================================================
fig, ax = plt.subplots(figsize=(12,6))
data_train['monhtly_avg'].plot(ax=ax, label='train')
data_test['monhtly_avg'].plot(ax=ax, label='test')
predictions.plot(ax=ax, label='predictions')
ax.legend();


error_mse = mean_squared_error(
                y_true = data_test,
                y_pred = predictions
            )

error_mae = mean_absolute_error(
                y_true = data_test,
                y_pred = predictions
            )

rsmes.append(error_mse**0.5)

maes.append(error_mae)

print(f"Mean Absolute Error (MAE): {error_mae:.2f}")

print(f"Root Mean Squared Error (RSME): {error_mse**0.5:.2f}")

print(f"Correlation Coefficient: {r2_score(data_test, predictions):.2f}")
r2s.append(r2_score(data_test, predictions))

# Vamos criar um gráfico para comparar os Valores Reais com os Preditos
fig = plt.figure(figsize=(8,8))
l = plt.plot(predictions.values, data_test.values, 'bo')
plt.setp(l, markersize=10)
plt.setp(l, markerfacecolor='C0')
plt.title('Comparação Valor Predito x Valor Real', fontsize=12)
plt.ylabel("True Value", fontsize=12)
plt.xlabel("Predict Value", fontsize=12)

# mostra os valores preditos e originais
xl = np.arange(min(data_test.values), 1.2*max(data_test.values),(max(data_test.values)-min(data_test.values))/10)
yl = xl
plt.plot(xl, yl, 'r--')
plt.show()
# Out:
# Mean Absolute Error (MAE): 65.30
# Root Mean Squared Error (RSME): 87.13
# Correlation Coefficient: 0.45

# %%
rank = pd.DataFrame({
    'Model': ['SARIMA (AIC)', 
              'SARIMA (GridSearch)', 
              'Random Forest (GridSearch)',
              'Long short-term memory'],
    'RSME': [f'{rsme:.2f}' for rsme in rsmes],
    'MAE': [f'{mae:.2f}' for mae in maes],
    'r² ': [f'{r2:.4f}' for r2 in r2s]})
rank.sort_values(by='RSME', ascending = True).set_index('Model')
# Out:
#                              RSME    MAE     r²
# Model
# Random Forest (GridSearch)  79.38  61.14  0.5463
# SARIMA (GridSearch)         87.15  66.97  0.4532
# SARIMA (AIC)                87.23  67.35  0.4522
# Long short-term memory      90.45  62.07  0.4109
